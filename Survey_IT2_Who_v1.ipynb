# %% [markdown]
# <a href="https://colab.research.google.com/github/patternproject/r.sb.gtm1/blob/main/Survey_IT2_Who_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
# Library
library(ggplot2)
library(tidyverse)
#install.packages("readxl")
library(readxl)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.5     ✔ dplyr   1.0.3
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# reading in input File
input_file = '/content/Without - Outlet Type - Size 3.xlsx'
df_master = read_xlsx(input_file, sheet=1)

# %%
# printing DF
print(as_tibble(df_master))
# Out:
# # A tibble: 9 x 3
#   City       Size       Value
#   <chr>      <chr>      <dbl>
# 1 Islamabad  Single   0.997
# 2 Islamabad  Multiple 0.00260
# 3 Islamabad  Chain    0
# 4 Rawalpindi Single   0.998
# 5 Rawalpindi Multiple 0.00171
# 6 Rawalpindi Chain    0
# 7 Karachi    Single   0.979
# 8 Karachi    Multiple 0.00415
# 9 Karachi    Chain    0.0166

# %%
g1 <- ggplot(data=df_master, aes(x=Size, y=Value, fill=Size)) +
  geom_bar(stat="identity", position=position_dodge())+
  theme_minimal()

# %%
# bars are too little to add data labels
g1 <- g1 + labs(x = "ORGANIZATION TYPE", y = "COUNT")
g1 <- g1 + scale_fill_brewer(palette = "Set2") 
g1 <- g1 + theme_light()
g1 <- g1 + theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
g1
# Out:
# plot without title

# %%
g11 <- g1 + theme(
    strip.text = element_text(face = "bold", size = rel(1.5)),
    strip.background = element_rect(fill = "lightgrey", colour = "black", size = 1),
    axis.title.y = element_blank(),
    legend.position = "none"
  )

g11
# Out:
# plot without title

# %%
g11 + facet_wrap(~ City)
# Out:
# plot without title
